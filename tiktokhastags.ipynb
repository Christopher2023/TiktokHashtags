# %%
import pandas as pd
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset_tiktok-scraper-task_2022-08-19_07-55-15-060.csv", header=0)
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (26,88,92,95,96,111,119,124,127,128,131,132,135,136,139,140,143,144,147,148,151,155,160,163,167,168,171,179,180,183,187,191,195,200,203,206,207,210,214,218,222,224,226,227,230,231,234,235,238,239,240,242,244,246,247,250,251,254,258,259,260,262,263,266,270,271,274,275,278,282,286,290,294,298,302,303,306,310,314,315,318,319,320,322,323,326,330,334,338,342,346,347,350,354,358,360,362,363,366,367,370,371,372,374,375,378,382,386,390,394,398,402,406,410,414,418,422,426,430,434,438,442,446,450,451,454,455,458,462,466,467,470,471,474,478,482,484,486,487,490,494,498,502,506,510,514,518,522,526,530,531,534,535,538,542,546,547,550,554,558,562,566,570,572,574,575,578,580,582,583,586,590,594,595,598,602,606,607,608,610,614,615,618,623,628,629) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df2 = df[["hashtags/0/name",
            "hashtags/1/name",
            "hashtags/2/name",
            "hashtags/3/name",
            "hashtags/4/name",
            "hashtags/5/name",
            "hashtags/6/name",
            "hashtags/7/name",
            "hashtags/8/name",
            "hashtags/9/name",
            "hashtags/10/name",
            "hashtags/11/name",
            "hashtags/12/name",
            "hashtags/13/name",
            "hashtags/14/name",
            "hashtags/15/name",
            "hashtags/16/name",
            "hashtags/17/name",
            "hashtags/18/name",
            "hashtags/19/name",
            "hashtags/20/name"]]

# %%
rows = []
for i in range (2910):
    rows.append(df2.iloc[i:i+1].to_string())

# %%
row = []
for i in range(len(rows)):
    row.append(re.sub(r"[0:9, NaN]"," "," ".join(filter(lambda x : x[0:4] != "hash", rows[i].split()))))

# %%
cloud = WordCloud(background_color='white', random_state=1)
image = cloud.generate(" ".join(row))
plt.imshow(image,interpolation = "bilinear")
plt.show()

# %%
rows = " ".join(row).split()

# %%
counts = []
count = 0
for word in rows:
	counts.append([word,rows.count(word)])

# %%
count
# Out:
# [['dropshipping', 974]]
